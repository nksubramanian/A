# %% [markdown]
# <a href="https://colab.research.google.com/github/nksubramanian/A/blob/main/Inference/Surg_instruments_inference_gradio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Inference from a saved model

# %%
# !wget https://raw.githubusercontent.com/airctic/icevision/master/icevision_install.sh
# !bash icevision_install.sh cuda11 master
# Out:
# --2022-10-27 10:59:25--  https://raw.githubusercontent.com/airctic/icevision/master/icevision_install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2820 (2.8K) [text/plain]
# Saving to: ‘icevision_install.sh.1’
#
# icevision_install.s 100%[===================>]   2.75K  --.-KB/s    in 0s
#
# 2022-10-27 10:59:25 (50.3 MB/s) - ‘icevision_install.sh.1’ saved [2820/2820]
#
# Installing icevision + dependencices for cuda11
# - Installing torch and its dependencies
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.10.0+cu111 in /usr/local/lib/python3.7/dist-packages (1.10.0+cu111)
# Requirement already satisfied: torchvision==0.11.1+cu111 in /usr/local/lib/python3.7/dist-packages (0.11.1+cu111)
# Requirement already satisfied: torchtext==0.11.0 in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.10.0+cu111) (4.1.1)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.11.1+cu111) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.11.1+cu111) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.11.0) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.11.0) (4.64.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.11.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.11.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.11.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.11.0) (2022.9.24)
# - Installing mmcv
# - Installing mmdet
# - Installing mmseg
# - Installing icevision from master
# - Installing icedata from master
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python-headless==4.1.2.30 in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless==4.1.2.30) (1.21.6)
# icevision installation finished!

# %%
import IPython
IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
import icevision
# Out:
# INFO     - The mmdet config folder already exists. No need to downloaded it. Path : /root/.icevision/mmdetection_configs/mmdetection_configs-2.20.1/configs | icevision.models.mmdet.download_configs:download_mmdet_configs:18
# INFO     - The mmseg config folder already exists. No need to downloaded it. Path : /root/.icevision/mmsegmentation_configs/mmsegmentation_configs-0.17.0/configs | icevision.models.mmseg.download_configs:download_mmseg_configs:20

# %%
from icevision.all import *

# %%
print('icevision v',icevision.__version__)
print('torch v',torch.__version__)
print('torchvision v',torchvision.__version__)
# Out:
# icevision v 0.12.0
# torch v 1.10.0+cu111
# torchvision v 0.11.1+cu111

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
root_dir = Path('/content/gdrive/My Drive/')

# %%
#!git clone https://github.com/yrodriguezmd/Surgical_instruments.git

# %%
classes = ['Army_navy', 'Bulldog', 'Castroviejo','Forceps', 'Frazier', 'Hemostat','Iris','Mayo_metz','Needle','Potts','Richardson','Scalpel','Towel_clip', 'Weitlaner','Yankauer']
class_map = ClassMap(classes)
len(class_map)
# Out:
# 16

# %%
metrics = [COCOMetric(metric_type=COCOMetricType.bbox)]

from icevision.models.checkpoint import *

model_type = models.mmdet.vfnet ##
backbone = model_type.backbones.resnet50_fpn_mstrain_2x##

# %%
# !ls gdrive/MyDrive/Surgical_instruments/Models
# Out:
# notebooks  README.md  VFNet_teacher_nov29_mAP82.6.pth

# %%
from icevision.models import *

checkpoint_path = root_dir/'Surgical_instruments/Models/VFNet_teacher_nov29_mAP82.6.pth' 

checkpoint_and_model = model_from_checkpoint(checkpoint_path)

model_loaded = checkpoint_and_model["model"]
# Out:
# load checkpoint from local path: /content/gdrive/My Drive/Surgical_instruments/Models/VFNet_teacher_nov29_mAP82.6.pth
# /usr/local/lib/python3.7/dist-packages/mmdet/core/anchor/builder.py:17: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   '``build_anchor_generator`` would be deprecated soon, please use '
# 2022-10-27 11:04:17,635 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2022-10-27 11:04:17,637 - mmcv - INFO - load model from: torchvision://resnet50
# 2022-10-27 11:04:17,643 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# 2022-10-27 11:04:18,537 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2022-10-27 11:04:18,582 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2022-10-27 11:04:18,615 - mmcv - INFO - initialize VFNetHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'vfnet_cls', 'std': 0.01, 'bias_prob': 0.01}}
# 2022-10-27 11:04:18,657 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,658 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,662 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,665 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,666 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,668 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,670 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,672 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,674 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,676 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,678 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,683 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,684 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,686 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,691 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,693 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,694 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,696 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,698 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,699 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,700 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,704 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,705 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,707 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,708 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,709 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,711 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,712 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,713 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,715 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,716 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,717 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,719 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,720 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,721 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,723 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,724 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,725 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,727 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,728 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,729 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,731 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,732 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,734 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,735 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,736 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,738 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,739 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,740 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,742 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,743 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,744 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,746 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,747 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,748 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,750 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,751 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,752 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,754 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,755 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,757 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,758 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,759 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,761 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,762 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,764 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,765 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,766 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,768 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,769 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,771 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,772 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,773 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,775 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,776 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,777 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,779 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,780 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,781 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,782 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,784 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,785 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,787 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,788 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,789 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,790 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,792 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,793 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,794 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,795 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,797 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,798 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,799 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,801 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,802 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,803 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,804 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,806 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,807 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,808 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,810 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,811 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,812 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,814 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,815 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,816 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,818 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,819 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,820 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,822 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,823 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,824 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,826 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,827 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,828 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,830 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,831 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,832 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,833 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,834 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,836 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,837 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,838 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,839 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,841 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,842 - mmcv - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,843 - mmcv - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,845 - mmcv - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,846 - mmcv - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,847 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,848 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,850 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,851 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,852 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,853 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,855 - mmcv - INFO -
# backbone.layer4.0.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,856 - mmcv - INFO -
# backbone.layer4.0.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,857 - mmcv - INFO -
# backbone.layer4.0.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,858 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([2048, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,860 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,861 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,862 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,864 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,865 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,866 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,868 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,869 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,870 - mmcv - INFO -
# backbone.layer4.1.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,872 - mmcv - INFO -
# backbone.layer4.1.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,873 - mmcv - INFO -
# backbone.layer4.1.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,874 - mmcv - INFO -
# backbone.layer4.2.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,875 - mmcv - INFO -
# backbone.layer4.2.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,877 - mmcv - INFO -
# backbone.layer4.2.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,878 - mmcv - INFO -
# backbone.layer4.2.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,879 - mmcv - INFO -
# backbone.layer4.2.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,881 - mmcv - INFO -
# backbone.layer4.2.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,882 - mmcv - INFO -
# backbone.layer4.2.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,884 - mmcv - INFO -
# backbone.layer4.2.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,885 - mmcv - INFO -
# backbone.layer4.2.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-10-27 11:04:18,886 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-10-27 11:04:18,888 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,889 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 1024, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-10-27 11:04:18,890 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,892 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 2048, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-10-27 11:04:18,893 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,894 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-10-27 11:04:18,896 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,897 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-10-27 11:04:18,898 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,900 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-10-27 11:04:18,901 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,902 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-10-27 11:04:18,904 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,905 - mmcv - INFO -
# neck.fpn_convs.4.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-10-27 11:04:18,906 - mmcv - INFO -
# neck.fpn_convs.4.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,908 - mmcv - INFO -
# bbox_head.cls_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-10-27 11:04:18,909 - mmcv - INFO -
# bbox_head.cls_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,910 - mmcv - INFO -
# bbox_head.cls_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,912 - mmcv - INFO -
# bbox_head.cls_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-10-27 11:04:18,913 - mmcv - INFO -
# bbox_head.cls_convs.1.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,914 - mmcv - INFO -
# bbox_head.cls_convs.1.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,916 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-10-27 11:04:18,917 - mmcv - INFO -
# bbox_head.cls_convs.2.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,918 - mmcv - INFO -
# bbox_head.cls_convs.2.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,920 - mmcv - INFO -
# bbox_head.reg_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-10-27 11:04:18,921 - mmcv - INFO -
# bbox_head.reg_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,922 - mmcv - INFO -
# bbox_head.reg_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,924 - mmcv - INFO -
# bbox_head.reg_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-10-27 11:04:18,925 - mmcv - INFO -
# bbox_head.reg_convs.1.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,927 - mmcv - INFO -
# bbox_head.reg_convs.1.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,928 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-10-27 11:04:18,929 - mmcv - INFO -
# bbox_head.reg_convs.2.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,931 - mmcv - INFO -
# bbox_head.reg_convs.2.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,932 - mmcv - INFO -
# bbox_head.vfnet_reg_conv.conv.weight - torch.Size([256, 256, 3, 3]):
# Initialized by user-defined `init_weights` in ConvModule
#
# 2022-10-27 11:04:18,933 - mmcv - INFO -
# bbox_head.vfnet_reg_conv.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,934 - mmcv - INFO -
# bbox_head.vfnet_reg_conv.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,935 - mmcv - INFO -
# bbox_head.vfnet_reg.weight - torch.Size([4, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-10-27 11:04:18,936 - mmcv - INFO -
# bbox_head.vfnet_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-10-27 11:04:18,938 - mmcv - INFO -
# bbox_head.scales.0.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,939 - mmcv - INFO -
# bbox_head.scales.1.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,940 - mmcv - INFO -
# bbox_head.scales.2.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,942 - mmcv - INFO -
# bbox_head.scales.3.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,943 - mmcv - INFO -
# bbox_head.scales.4.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,944 - mmcv - INFO -
# bbox_head.vfnet_reg_refine_dconv.weight - torch.Size([256, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,946 - mmcv - INFO -
# bbox_head.vfnet_reg_refine.weight - torch.Size([4, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-10-27 11:04:18,947 - mmcv - INFO -
# bbox_head.vfnet_reg_refine.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-10-27 11:04:18,948 - mmcv - INFO -
# bbox_head.scales_refine.0.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,950 - mmcv - INFO -
# bbox_head.scales_refine.1.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,951 - mmcv - INFO -
# bbox_head.scales_refine.2.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,952 - mmcv - INFO -
# bbox_head.scales_refine.3.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,953 - mmcv - INFO -
# bbox_head.scales_refine.4.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,955 - mmcv - INFO -
# bbox_head.vfnet_cls_dconv.weight - torch.Size([256, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2022-10-27 11:04:18,956 - mmcv - INFO -
# bbox_head.vfnet_cls.weight - torch.Size([15, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2022-10-27 11:04:18,957 - mmcv - INFO -
# bbox_head.vfnet_cls.bias - torch.Size([15]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459

# %%
# !ls gdrive/MyDrive/Surgical_instruments/Second_set.v1i.coco
# Out:
# ls: cannot access 'gdrive/MyDrive/Surgical_instruments/Second_set.v1i.coco': No such file or directory

# %%
path = Path('gdrive/MyDrive/Surgical_instruments/Sets/Second_set') # 

test_parser = parsers.COCOBBoxParser(
    annotations_filepath = path/'test/_annotations.coco.json',
    img_dir = path/'test')

whole = SingleSplitSplitter()

test_records, *_ = test_parser.parse(data_splitter = whole)

#show_records(test_records[0:3],ncols=3, font_size=30, label_color = '#ffff00')
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# INFO     - Autofixing records | icevision.parsers.parser:parse:122
#   0%|          | 0/19 [00:00<?, ?it/s]

# %%
img_size = checkpoint_and_model["img_size"]

valid_tfms = tfms.A.Adapter([*tfms.A.resize_and_pad(img_size), tfms.A.Normalize()])

#infer_ds = Dataset.from_images(imgs_array, valid_tfms, class_map = class_map)
infer_ds = Dataset(test_records, valid_tfms)#, class_map = class_map)

# %%
infer_dl = model_type.infer_dl(infer_ds, 
                               batch_size=4, shuffle=False)

preds_saved_test = model_type.predict_from_dl(model_loaded,#
                                              infer_dl,
                                          keep_images=True, 
                                         detection_threshold = 0.5) ##
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
show_preds(preds = preds_saved_test[0:10])
# with detection threshold 0.5

# %% [markdown]
# Gradio deployment using saved model

# %%
show_sample(preds_saved_test[3])
preds_saved_test[3].pred
# Out:
# BaseRecord
#
# common:
# 	- Img: 384x384x3 <np.ndarray> Image
# 	- Image size ImgSize(width=384, height=384)
# 	- Record ID: 3
# detection:
# 	- BBoxes: [<BBox (xmin:148.4886474609375, ymin:35.694854736328125, xmax:225.17855834960938, ymax:369.2015380859375)>]
# 	- Class Map: <ClassMap: {'background': 0, 'Army_navy': 1, 'Bulldog': 2, 'Castroviejo': 3, 'Forceps': 4, 'Frazier': 5, 'Hemostat': 6, 'Iris': 7, 'Mayo_metz': 8, 'Needle': 9, 'Potts': 10, 'Richardson': 11, 'Scalpel': 12, 'Towel_clip': 13, 'Weitlaner': 14, 'Yankauer': 15}>
# 	- Labels: [15]
# 	- Scores: [    0.81701]

# %%
# !echo "- Installing gradio"
# !pip install gradio -U -q
import icedata
import PIL, requests
import torch
from torchvision import transforms
import gradio as gr

def show_preds_gradio(input_image, display_label, display_bbox, detection_threshold):

    if detection_threshold==0: detection_threshold=0.5

    img = PIL.Image.fromarray(input_image, 'RGB')

    pred_dict  = model_type.end2end_detect(img, 
                                           valid_tfms, 
                                           model_loaded, ## 
                                           class_map=class_map, 
                                           detection_threshold=detection_threshold,
                                           display_label=display_label, 
                                           display_bbox=display_bbox, 
                                           return_img=True, 
                                           font_size=16, 
                                           label_color="#FF59D6")

    return pred_dict['img']

# %%
display_chkbox_label = gr.inputs.Checkbox(label="Label", default=True)
display_chkbox_box = gr.inputs.Checkbox(label="Box", default=True)

detection_threshold_slider = gr.inputs.Slider(minimum=0, maximum=1, step=0.1, default=0.5, label="Detection Threshold")

outputs = gr.outputs.Image(type="pil")

# Option 1: Get an image from local drive
gr_interface = gr.Interface(fn=show_preds_gradio, inputs=["image", display_chkbox_label, display_chkbox_box,  detection_threshold_slider], outputs=outputs, title='IceApp - COCO')

# %%
gr_interface.launch(inline=False, share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://13840.gradio.app
#
# This share link will expire in 72 hours. To get longer links, send an email to: support@gradio.app
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-009d703f2f3b> in <module>()
# ----> 1 gr_interface.launch(inline=False, share=True, debug=True)
#
# /usr/local/lib/python3.7/dist-packages/gradio/interface.py in launch(self, inline, inbrowser, share, debug, auth, auth_message, private_endpoint, prevent_thread_lock, show_error)
#     644             while True:
#     645                 sys.stdout.flush()
# --> 646                 time.sleep(0.1)
#     647         is_in_interactive_mode = bool(
#     648             getattr(sys, 'ps1', sys.flags.interactive))
#
# KeyboardInterrupt:
